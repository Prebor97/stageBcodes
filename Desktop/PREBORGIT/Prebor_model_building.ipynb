# %%
import numpy as np
import pandas as pd
foreignEx_data = pd.read_csv('Foreign_Exchange_Rates.csv', parse_dates=['Time Serie'],index_col = 'Time Serie', na_values = 'ND') # na_values was used to classify any value with ND as null

# %%
foreignEx_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5217 entries, 2000-01-03 to 2019-12-31
# Data columns (total 23 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 5217 non-null   int64
#  1   AUSTRALIA - AUSTRALIAN DOLLAR/US$          5019 non-null   float64
#  2   EURO AREA - EURO/US$                       5019 non-null   float64
#  3   NEW ZEALAND - NEW ZELAND DOLLAR/US$        5019 non-null   float64
#  4   UNITED KINGDOM - UNITED KINGDOM POUND/US$  5019 non-null   float64
#  5   BRAZIL - REAL/US$                          5019 non-null   float64
#  6   CANADA - CANADIAN DOLLAR/US$               5019 non-null   float64
#  7   CHINA - YUAN/US$                           5020 non-null   float64
#  8   HONG KONG - HONG KONG DOLLAR/US$           5019 non-null   float64
# ...

# %%
foreignEx_data.head(10)
# Out:
#             Unnamed: 0  AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# Time Serie
# 2000-01-03           0                             1.5172
# 2000-01-04           1                             1.5239
# 2000-01-05           2                             1.5267
# 2000-01-06           3                             1.5291
# 2000-01-07           4                             1.5272
# 2000-01-10           5                             1.5242
# 2000-01-11           6                             1.5209
# 2000-01-12           7                             1.5202
# 2000-01-13           8                             1.4954
# 2000-01-14           9                             1.5004
#
#             EURO AREA - EURO/US$  NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# Time Serie
# 2000-01-03                0.9847                               1.9033
# 2000-01-04                0.9700                               1.9238
# 2000-01-05                0.9676                               1.9339
# ...

# %%
corel_plot = foreignEx_data.corr()

# %%
corel_plot
# Out:
#                                            Unnamed: 0  \
# Unnamed: 0                                   1.000000
# AUSTRALIA - AUSTRALIAN DOLLAR/US$           -0.519120
# EURO AREA - EURO/US$                        -0.339503
# NEW ZEALAND - NEW ZELAND DOLLAR/US$         -0.645185
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    0.518524
# BRAZIL - REAL/US$                            0.448859
# CANADA - CANADIAN DOLLAR/US$                -0.358527
# CHINA - YUAN/US$                            -0.842322
# HONG KONG - HONG KONG DOLLAR/US$             0.013402
# INDIA - INDIAN RUPEE/US$                     0.842671
# KOREA - WON/US$                             -0.120677
# MEXICO - MEXICAN PESO/US$                    0.906443
# SOUTH AFRICA - RAND/US$                      0.746723
# SINGAPORE - SINGAPORE DOLLAR/US$            -0.838127
# DENMARK - DANISH KRONE/US$                  -0.336960
# JAPAN - YEN/US$                             -0.246617
# ...

# %%
foreignEx_data.isnull().sum()# Checked for null values
# Out:
# Unnamed: 0                                     0
# Time Serie                                     0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            198
# EURO AREA - EURO/US$                         198
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          198
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    198
# BRAZIL - REAL/US$                            198
# CANADA - CANADIAN DOLLAR/US$                 198
# CHINA - YUAN/US$                             197
# HONG KONG - HONG KONG DOLLAR/US$             198
# INDIA - INDIAN RUPEE/US$                     199
# KOREA - WON/US$                              198
# MEXICO - MEXICAN PESO/US$                    198
# SOUTH AFRICA - RAND/US$                      198
# SINGAPORE - SINGAPORE DOLLAR/US$             198
# DENMARK - DANISH KRONE/US$                   198
# JAPAN - YEN/US$                              198
# MALAYSIA - RINGGIT/US$                       198
# NORWAY - NORWEGIAN KRONE/US$                 198
# ...

# %%
foreignEx_data = foreignEx_data.bfill().ffill()

# %%
foreignEx_data.isnull().sum()
# Out:
# Unnamed: 0                                   0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            0
# EURO AREA - EURO/US$                         0
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          0
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    0
# BRAZIL - REAL/US$                            0
# CANADA - CANADIAN DOLLAR/US$                 0
# CHINA - YUAN/US$                             0
# HONG KONG - HONG KONG DOLLAR/US$             0
# INDIA - INDIAN RUPEE/US$                     0
# KOREA - WON/US$                              0
# MEXICO - MEXICAN PESO/US$                    0
# SOUTH AFRICA - RAND/US$                      0
# SINGAPORE - SINGAPORE DOLLAR/US$             0
# DENMARK - DANISH KRONE/US$                   0
# JAPAN - YEN/US$                              0
# MALAYSIA - RINGGIT/US$                       0
# NORWAY - NORWEGIAN KRONE/US$                 0
# SWEDEN - KRONA/US$                           0
# SRI LANKA - SRI LANKAN RUPEE/US$             0
# ...

# %%
df_1 = foreignEx_data['INDIA - INDIAN RUPEE/US$']

# %%
print(df_1.head(10))
# Out:
# Time Serie
# 2000-01-03    43.55
# 2000-01-04    43.55
# 2000-01-05    43.55
# 2000-01-06    43.55
# 2000-01-07    43.55
# 2000-01-10    43.55
# 2000-01-11    43.60
# 2000-01-12    43.60
# 2000-01-13    43.55
# 2000-01-14    43.55
# Name: INDIA - INDIAN RUPEE/US$, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(foreignEx_data['INDIA - INDIAN RUPEE/US$'])# plotted the rate for india to see how it looks. We can also do it for any country we may be interested in work on

# %%
foreignEx_data['INDIA - INDIAN RUPEE/US$'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
df = foreignEx_data['SOUTH AFRICA - RAND/US$']# Did same for south africa

# %%
print (df)
# Out:
# Time Serie
# 2000-01-03     6.126
# 2000-01-04     6.085
# 2000-01-05     6.070
# 2000-01-06     6.080
# 2000-01-07     6.057
#                ...
# 2019-12-25    14.132
# 2019-12-26    14.132
# 2019-12-27    14.025
# 2019-12-30    14.056
# 2019-12-31    13.973
# Name: SOUTH AFRICA - RAND/US$, Length: 5217, dtype: float64

# %%
print (df.head(15))
# Out:
# 0     6.1260
# 1     6.0850
# 2     6.0700
# 3     6.0800
# 4     6.0570
# 5     6.0765
# 6     6.0900
# 7     6.0685
# 8     6.0570
# 9     6.0750
# 10       NaN
# 11    6.0890
# 12    6.1140
# 13    6.1000
# 14    6.1280
# Name: SOUTH AFRICA - RAND/US$, dtype: float64

# %%
plt.plot(foreignEx_data['SOUTH AFRICA - RAND/US$'])
plt.show()

# %%
print(df.tail(5))
# Out:
# 5212       NaN
# 5213    14.132
# 5214    14.025
# 5215    14.056
# 5216    13.973
# Name: SOUTH AFRICA - RAND/US$, dtype: float64

# %%
foreignEx_data['SOUTH AFRICA - RAND/US$'].max()# I want to know when the rate was at its highest and what date it happened
# Out:
# 16.8845

# %%
plt.plot(foreignEx_data['SOUTH AFRICA - RAND/US$'])

# %%
SAforeign = foreignEx_data['SOUTH AFRICA - RAND/US$'].iloc[4100:4200] # tried locating it but i couldnt. So i manually checked for the date using the graph as my guide

# %%
print (SAforeign.tail(50))
# Out:
# 4150    14.4800
# 4151    14.4325
# 4152    14.3750
# 4153    14.3700
# 4154    14.3255
# 4155    14.5425
# 4156    14.6000
# 4157    14.5775
# 4158    15.2519
# 4159    15.7510
# 4160    15.1465
# 4161    14.9815
# 4162    15.0725
# 4163    15.2060
# 4164    15.0435
# 4165    15.1045
# 4166    15.1855
# 4167    15.1845
# 4168    15.2740
# 4169        NaN
# 4170    15.2935
# 4171    15.2885
# 4172    15.5795
# 4173    15.4660
# 4174        NaN
# 4175    15.6150
# 4176    15.6260
# 4177    15.7855
# 4178    15.9740
# 4179    16.1800
# 4180    16.8025
# 4181    16.7125
# 4182    16.3905
# 4183    16.4305
# 4184    16.8125
# 4185        NaN
# 4186    16.6930
# 4187    16.8845
# 4188    16.5125
# 4189    16.4625
# 4190    16.4510
# 4191    16.3535
# 4192    16.3355
# 4193    16.1995
# 4194    15.9535
# 4195    15.9480
# 4196    16.1835
# 4197    16.1400
# 4198    15.8305
# 4199    15.9785
# Name: SOUTH AFRICA - RAND/US$, dtype: float64

# %%
foreignEx_data.iloc[5216]# this was the location and the date
# Out:
# Unnamed: 0                                         5216
# Time Serie                                   2019-12-31
# AUSTRALIA - AUSTRALIAN DOLLAR/US$                1.4225
# EURO AREA - EURO/US$                             0.8907
# NEW ZEALAND - NEW ZELAND DOLLAR/US$              1.4826
# UNITED KINGDOM - UNITED KINGDOM POUND/US$        0.7536
# BRAZIL - REAL/US$                                 4.019
# CANADA - CANADIAN DOLLAR/US$                     1.2962
# CHINA - YUAN/US$                                 6.9618
# HONG KONG - HONG KONG DOLLAR/US$                 7.7894
# INDIA - INDIAN RUPEE/US$                          71.36
# KOREA - WON/US$                                 1155.46
# MEXICO - MEXICAN PESO/US$                         18.86
# SOUTH AFRICA - RAND/US$                          13.973
# SINGAPORE - SINGAPORE DOLLAR/US$                 1.3446
# DENMARK - DANISH KRONE/US$                       6.6554
# JAPAN - YEN/US$                                  108.67
# ...

# %%
foreignEx_data['SOUTH AFRICA - RAND/US$'].min()# I want to know when the rate was at its lowest and what date it happened
# Out:
# 5.615

# %%
SAforeign_1 = foreignEx_data['SOUTH AFRICA - RAND/US$'].iloc[1290:1310] #I manually checked for the date using the graph as my guide

# %%
print(SAforeign_1)
# Out:
# 1290    5.7350
# 1291    5.7350
# 1292    5.7350
# 1293    5.7725
# 1294    5.7800
# 1295    5.7200
# 1296    5.6745
# 1297    5.6525
# 1298    5.6400
# 1299    5.6150
# 1300    5.6150
# 1301    5.6250
# 1302    5.7000
# 1303    5.6288
# 1304    5.6450
# 1305    5.6425
# 1306    5.8600
# 1307    5.8950
# 1308    6.1030
# 1309    6.0965
# Name: SOUTH AFRICA - RAND/US$, dtype: float64

# %%
print(SAforeign_1.tail(20))
# Out:
# 1290    5.7350
# 1291    5.7350
# 1292    5.7350
# 1293    5.7725
# 1294    5.7800
# 1295    5.7200
# 1296    5.6745
# 1297    5.6525
# 1298    5.6400
# 1299    5.6150
# 1300    5.6150
# 1301    5.6250
# 1302    5.7000
# 1303    5.6288
# 1304    5.6450
# 1305    5.6425
# 1306    5.8600
# 1307    5.8950
# 1308    6.1030
# 1309    6.0965
# Name: SOUTH AFRICA - RAND/US$, dtype: float64

# %%
foreignEx_data.iloc[1299]# this was the location and the date
# Out:
# Unnamed: 0                                         1299
# Time Serie                                   2004-12-24
# AUSTRALIA - AUSTRALIAN DOLLAR/US$                1.3006
# EURO AREA - EURO/US$                             0.7388
# NEW ZEALAND - NEW ZELAND DOLLAR/US$              1.3937
# UNITED KINGDOM - UNITED KINGDOM POUND/US$        0.5199
# BRAZIL - REAL/US$                                  2.69
# CANADA - CANADIAN DOLLAR/US$                     1.2291
# CHINA - YUAN/US$                                 8.2765
# HONG KONG - HONG KONG DOLLAR/US$                 7.7819
# INDIA - INDIAN RUPEE/US$                          43.63
# KOREA - WON/US$                                  1047.8
# MEXICO - MEXICAN PESO/US$                        11.143
# SOUTH AFRICA - RAND/US$                           5.615
# SINGAPORE - SINGAPORE DOLLAR/US$                 1.6392
# DENMARK - DANISH KRONE/US$                       5.4963
# JAPAN - YEN/US$                                  103.65
# ...

# %%
foreignEx_data['SOUTH AFRICA - RAND/US$'].mean()# Just calculated their mean rate over the entire period
# Out:
# 9.420282626021118

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
foreignEx_data_1 = foreignEx_data.iloc[0:5216, 2:22]# Tried plotting a heat map but was unable to because of the time serie, so i worked my way around it by removing the time serie(date) entirely before i plotted it

# %%
print (foreignEx_data_1.head(5))# the data after date have been removed
# Out:
#    AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0                             1.5172                0.9847
# 1                             1.5239                0.9700
# 2                             1.5267                0.9676
# 3                             1.5291                0.9686
# 4                             1.5272                0.9714
#
#    NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                               1.9033
# 1                               1.9238
# 2                               1.9339
# 3                               1.9436
# 4                               1.9380
#
#    UNITED KINGDOM - UNITED KINGDOM POUND/US$  BRAZIL - REAL/US$  \
# 0                                     0.6146             1.8050
# 1                                     0.6109             1.8405
# 2                                     0.6092             1.8560
# 3                                     0.6070             1.8400
# ...

# %%
corel_plot = sns.heatmap(data = foreignEx_data_1.corr())# the correlation plot
plt.show()# From the plot i saw south africa and india's rates has high correlation among others too. I fitted a linear model to both and trained them.

# %%
foreignEx_data_1.describe()
# Out:
#        AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# count                        5018.000000           5018.000000
# mean                            1.331997              0.843895
# std                             0.269942              0.126847
# min                             0.906900              0.624600
# 25%                             1.115200              0.750800
# 50%                             1.311000              0.815550
# 75%                             1.430200              0.900100
# max                             2.071300              1.209200
#
#        NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# count                          5018.000000
# mean                              1.543695
# std                               0.337350
# min                               1.134600
# 25%                               1.323800
# 50%                               1.442400
# 75%                               1.591100
# max                               2.551000
#
# ...

# %%
foreignEX_1 = foreignEx_data[['SOUTH AFRICA - RAND/US$','UNITED KINGDOM - UNITED KINGDOM POUND/US$','INDIA - INDIAN RUPEE/US$']]

# %%
foreignEX_1.corr()
# Out:
#                                            SOUTH AFRICA - RAND/US$  \
# SOUTH AFRICA - RAND/US$                                   1.000000
# UNITED KINGDOM - UNITED KINGDOM POUND/US$                 0.771366
# INDIA - INDIAN RUPEE/US$                                  0.926701
#
#                                            UNITED KINGDOM - UNITED KINGDOM POUND/US$  \
# SOUTH AFRICA - RAND/US$                                                     0.771366
# UNITED KINGDOM - UNITED KINGDOM POUND/US$                                   1.000000
# INDIA - INDIAN RUPEE/US$                                                    0.752094
#
#                                            INDIA - INDIAN RUPEE/US$
# SOUTH AFRICA - RAND/US$                                    0.926701
# UNITED KINGDOM - UNITED KINGDOM POUND/US$                  0.752094
# INDIA - INDIAN RUPEE/US$                                   1.000000

# %% [markdown]
# From the above correlation, we can see that india and south africa are strongly correlated, so we are going to get good prediction when we run a linear regression model on them. Also, if though the correlation is not as high as that of south africa and india, we can run a linear regression between the UK and any of the other two countries.

# %% [markdown]
# You run the risk of overfitting (model will not predict well on new data) if we use linear model just like that. As such I am going to try either lasso or ridge so as to prevent overfitting

# %%
sns.regplot(x='SOUTH AFRICA - RAND/US$', y='INDIA - INDIAN RUPEE/US$',data=foreignEX_1)
# Out:
# <AxesSubplot:xlabel='SOUTH AFRICA - RAND/US$', ylabel='INDIA - INDIAN RUPEE/US$'>

# %%
main_data_1 = foreignEX_1.iloc[:4174,:3]

# %%
main_data_1.tail()
# Out:
#             SOUTH AFRICA - RAND/US$  \
# Time Serie
# 2015-12-25                  15.2935
# 2015-12-28                  15.2935
# 2015-12-29                  15.2885
# 2015-12-30                  15.5795
# 2015-12-31                  15.4660
#
#             UNITED KINGDOM - UNITED KINGDOM POUND/US$  \
# Time Serie
# 2015-12-25                                     0.6719
# 2015-12-28                                     0.6719
# 2015-12-29                                     0.6759
# 2015-12-30                                     0.6742
# 2015-12-31                                     0.6782
#
#             INDIA - INDIAN RUPEE/US$
# Time Serie
# 2015-12-25                     66.09
# 2015-12-28                     66.09
# 2015-12-29                     66.28
# 2015-12-30                     66.44
# 2015-12-31                     66.19

# %%
out_sample_data_1 = foreignEX_1.iloc[4174:,:3]

# %%
out_sample_data_1.head()
# Out:
#             SOUTH AFRICA - RAND/US$  \
# Time Serie
# 2016-01-01                  15.6150
# 2016-01-04                  15.6150
# 2016-01-05                  15.6260
# 2016-01-06                  15.7855
# 2016-01-07                  15.9740
#
#             UNITED KINGDOM - UNITED KINGDOM POUND/US$  \
# Time Serie
# 2016-01-01                                     0.6809
# 2016-01-04                                     0.6809
# 2016-01-05                                     0.6819
# 2016-01-06                                     0.6837
# 2016-01-07                                     0.6859
#
#             INDIA - INDIAN RUPEE/US$
# Time Serie
# 2016-01-01                     66.56
# 2016-01-04                     66.56
# 2016-01-05                     66.49
# 2016-01-06                     66.71
# 2016-01-07                     66.73

# %% [markdown]
# So basically what I am trying to do is to create two datasets. One for training the model and the other for testing the accuracy by actually running the model on an out of sample data(seemingly new data) and comparing the values.

# %%
main_data_2 = main_data_1[['SOUTH AFRICA - RAND/US$', 'INDIA - INDIAN RUPEE/US$' ]]

# %%
out_sample_data_2 = out_sample_data_1[['SOUTH AFRICA - RAND/US$', 'INDIA - INDIAN RUPEE/US$']]

# %%
out_of_sample_data_2 = out_sample_data_2.drop(columns = 'INDIA - INDIAN - INDIAN RUPEE/US$')

# %%
columns = ({'INDIA - INDIAN - INDIAN RUPEE/US$':'INDIA - INDIAN RUPEE/US$'})

# %%
out_of_sample_data_2 = out_of_sample_data_2.drop(columns = 'INDIA - INDIAN - INDIAN RUPEE/US$')

# %%
out_of_sample_data_2['INDIA - INDIAN RUPEE/US$'] = np.nan

# %%
out_of_sample_data_2['INDIA - INDIAN RUPEE/US$'].astype('float')
# Out:
# Time Serie
# 2016-01-01   NaN
# 2016-01-04   NaN
# 2016-01-05   NaN
# 2016-01-06   NaN
# 2016-01-07   NaN
#               ..
# 2019-12-25   NaN
# 2019-12-26   NaN
# 2019-12-27   NaN
# 2019-12-30   NaN
# 2019-12-31   NaN
# Name: INDIA - INDIAN RUPEE/US$, Length: 1043, dtype: float64

# %%
main_data_3 = main_data_1[['SOUTH AFRICA - RAND/US$', 'UNITED KINGDOM - UNITED KINGDOM POUND/US$']]

# %%
out_sample_data_3 = out_sample_data_1[['SOUTH AFRICA - RAND/US$', 'UNITED KINGDOM - UNITED KINGDOM POUND/US$']]

# %%
import sklearn

# %%
target_rate_1 = main_data_2['INDIA - INDIAN RUPEE/US$']
target_rate_2 = main_data_3['UNITED KINGDOM - UNITED KINGDOM POUND/US$']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(main_data_2, target_rate_1, test_size = 0.3, random_state = 2)

# %%
x_train,x_test, y_train, y_test = train_test_split(main_data_3, target_rate_1, test_size = 0.3, random_state = 2)

# %%
from sklearn.linear_model import Ridge
ridge_reg_1 = Ridge(alpha=1)
ridge_reg_1.fit(x_train, y_train)
predicted_values_2 = ridge_reg_1.predict(x_test)

# %%
predicted_values_2
# Out:
# array([44.40858358, 47.61900183, 46.33350844, ..., 60.84737213,
#        43.99222019, 49.85046472])

# %%
ridge_reg_1.score(x_train,y_train)
# Out:
# 0.6891400573671282

# %%
ridge_reg_1.score(x_test,y_test)
# Out:
# 0.6802970176998383

# %%
filename_1 = 'finalized_model_1.sav'
pickle.dump(ridge_reg_1,open(filename_1,'wb'))

# %%
loaded_model_1 = pickle.load(open(filename_1, 'rb'))

# %%
UK_forecast = loaded_model_1.predict(out_sample_data_3)

# %%
UK_forecastSe = pd.Series(UK_forecast)

# %%
out_sample_data_3.tail()
# Out:
#             SOUTH AFRICA - RAND/US$  UNITED KINGDOM - UNITED KINGDOM POUND/US$
# Time Serie
# 2019-12-25                   14.132                                     0.7688
# 2019-12-26                   14.132                                     0.7688
# 2019-12-27                   14.025                                     0.7639
# 2019-12-30                   14.056                                     0.7610
# 2019-12-31                   13.973                                     0.7536

# %%
UK_forecastSe.tail()
# Out:
# 1038    66.633743
# 1039    66.633743
# 1040    66.303016
# 1041    66.384250
# 1042    66.115554
# dtype: float64

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1)
ridge_reg.fit(x_train, y_train)
predicted_values_1 = ridge_reg.predict(x_test)

# %%
ridge_reg.score(x_train,y_train)
# Out:
# 0.9999999998159598

# %%
ridge_reg.score(x_test,y_test)
# Out:
# 0.9999999998111012

# %% [markdown]
# I want to save the model so I can make prediction with it on my out of sample data

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(ridge_reg,open(filename,'wb'))

# %% [markdown]
# Now I want to apply the model on an out of sample data

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
indian_forecast = loaded_model.predict(out_of_sample_data_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [179], in <cell line: 1>()
# ----> 1 indian_forecast = loaded_model.predict(out_of_sample_data_2)
#
# File C:\Users\just python\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File C:\Users\just python\lib\site-packages\sklearn\linear_model\_base.py:345, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
#     343     check_is_fitted(self)
# --> 345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
indian_forecastSe = pd.Series(indian_forecast)

# %%
indian_forecastSe.shape
# Out:
# (1043,)

# %%
out_of_sample_data_2.shape
# Out:
# (1043, 2)

# %%
indian_forecastSe[50:80]
# Out:
# 50    0.001691
# 51    0.001717
# 52    0.001745
# 53    0.001759
# 54    0.001688
# 55    0.001695
# 56    0.001688
# 57    0.001692
# 58    0.001700
# 59    0.001715
# 60    0.001711
# 61    0.001718
# 62    0.001703
# 63    0.001668
# 64    0.001656
# 65    0.001657
# 66    0.001653
# 67    0.001682
# 68    0.001685
# 69    0.001687
# 70    0.001674
# 71    0.001655
# 72    0.001654
# 73    0.001646
# 74    0.001642
# 75    0.001646
# 76    0.001639
# 77    0.001625
# 78    0.001620
# 79    0.001624
# dtype: float64

# %%
out_of_sample_data_2[50:80]
# Out:
#             SOUTH AFRICA - RAND/US$  INDIA - INDIAN RUPEE/US$
# Time Serie
# 2016-03-11                  15.2005                     66.93
# 2016-03-14                  15.5555                     67.15
# 2016-03-15                  15.9450                     67.33
# 2016-03-16                  16.1400                     67.24
# 2016-03-17                  15.1610                     66.61
# 2016-03-18                  15.2560                     66.34
# 2016-03-21                  15.1560                     66.45
# 2016-03-22                  15.2190                     66.58
# 2016-03-23                  15.3215                     66.82
# 2016-03-24                  15.5225                     66.82
# 2016-03-25                  15.4675                     66.82
# 2016-03-28                  15.5755                     66.58
# 2016-03-29                  15.3655                     66.46
# 2016-03-30                  14.8870                     66.37
# ...
